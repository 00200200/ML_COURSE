# %%
from google.colab import drive
drive.mount('drive')
import pandas as pd
import numpy as np
cars_df = pd.read_csv('/content/drive/MyDrive/CL/Day 4/car_data.csv', sep=',' )

cars_df
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
#       Unnamed: 0          id    price   manufacturer    model  prod_year  \
# 0              0  45654403.0  13328.0          LEXUS   RX 450     2010.0
# 1              1  44731507.0  16621.0      CHEVROLET  Equinox     2011.0
# 2              2  45774419.0   8467.0          HONDA      FIT     2006.0
# 3              3  45769185.0   3607.0           FORD   Escape     2011.0
# 4              4  45809263.0  11726.0          HONDA      FIT     2014.0
# ...          ...         ...      ...            ...      ...        ...
# 19232      19232  45798355.0   8467.0  MERCEDES-BENZ  CLK 200     1999.0
# 19233      19233  45778856.0  15681.0        HYUNDAI   Sonata     2011.0
# 19234      19234  45804997.0  26108.0        HYUNDAI   Tucson     2010.0
# 19235      19235  45793526.0   5331.0      CHEVROLET  Captiva     2007.0
# ...

# %%
cars_df.drop(['Unnamed: 0'],inplace=True,axis=1)
cars_df
# Out:
#                id    price   manufacturer    model  prod_year   category  \
# 0      45654403.0  13328.0          LEXUS   RX 450     2010.0       Jeep
# 1      44731507.0  16621.0      CHEVROLET  Equinox     2011.0       Jeep
# 2      45774419.0   8467.0          HONDA      FIT     2006.0  Hatchback
# 3      45769185.0   3607.0           FORD   Escape     2011.0       Jeep
# 4      45809263.0  11726.0          HONDA      FIT     2014.0  Hatchback
# ...           ...      ...            ...      ...        ...        ...
# 19232  45798355.0   8467.0  MERCEDES-BENZ  CLK 200     1999.0      Coupe
# 19233  45778856.0  15681.0        HYUNDAI   Sonata     2011.0      Sedan
# 19234  45804997.0  26108.0        HYUNDAI   Tucson     2010.0       Jeep
# 19235  45793526.0   5331.0      CHEVROLET  Captiva     2007.0       Jeep
# 19236  45813273.0    470.0        HYUNDAI   Sonata     2012.0      Sedan
#
#       leather_interior fuel_type  engine_volume   mileage  cylinders  \
# ...

# %%
# !pip install ydata_profiling

import ydata_profiling as ydp

cars_report = ydp.ProfileReport(cars_df)
cars_report
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cars_df.dropna(inplace=True)

# %%
cars_df.drop(['id'],inplace=True,axis=1)

# %%
cars_df = pd.get_dummies(cars_df,drop_first=True)

# %%
cars_df
# Out:
#          price  prod_year  engine_volume   mileage  cylinders  airbags  \
# 0      13328.0     2010.0            3.5  186005.0        6.0     12.0
# 1      16621.0     2011.0            3.0  192000.0        6.0      8.0
# 2       8467.0     2006.0            1.3  200000.0        4.0      2.0
# 3       3607.0     2011.0            2.5  168966.0        4.0      0.0
# 4      11726.0     2014.0            1.3   91901.0        4.0      4.0
# ...        ...        ...            ...       ...        ...      ...
# 19232   8467.0     1999.0            2.0  300000.0        4.0      5.0
# 19233  15681.0     2011.0            2.4  161600.0        4.0      8.0
# 19234  26108.0     2010.0            2.0  116365.0        4.0      4.0
# 19235   5331.0     2007.0            2.0   51258.0        4.0      4.0
# 19236    470.0     2012.0            2.4  186923.0        4.0     12.0
#
#        manufacturer_ALFA ROMEO  manufacturer_ASTON MARTIN  manufacturer_AUDI  \
# ...

# %%
from sklearn.model_selection import train_test_split

X = cars_df.drop(['price'],axis=1)
y = cars_df['price']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(random_state=42,n_jobs=-1)

params = {
    'max_depth': [10, 15, 20, None],
    'min_samples_leaf': [1, 2, 4],
    'n_estimators': [100, 200, 300]
}
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator=rf_regressor, param_grid=params, cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 100}

# %%
model = grid_search.best_estimator_

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
