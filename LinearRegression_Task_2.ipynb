# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_file = 'drive/MyDrive/CL/Day_1/diamonds.csv'
import pandas as pd
diamonds_df = pd.read_csv(path_to_file)
diamonds_df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# Wyświetl kilkanaście pierwszych rekordów danych, aby sprawdzić, jak wyglądają dane.
diamonds_df.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48
# 6  3.98  2.47
# 7  4.11  2.53
# 8  3.78  2.49
# ...

# %%
diamonds_df.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
diamonds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

object_columns = diamonds_df.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
for column in object_columns:
  diamonds_df[column] = le.fit_transform(diamonds_df[column])

# %%
diamonds_df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Wykorzystaj odpowiednie narzędzie biblioteki seaborn, aby sprawdzić relacje między zmiennymi i dystrybucję wartości zmiennych na jednym wykresie.
import seaborn as sns
import matplotlib.pyplot as plt

matrix_corr = diamonds_df.corr()

# %%
plt.figure(figsize=(16,8))
sns.heatmap(matrix_corr,annot=True,cmap='coolwarm',fmt=".2f")
sns.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-e160613a7bca> in <cell line: 3>()
#       1 plt.figure(figsize=(16,8))
#       2 sns.heatmap(matrix_corr,annot=True,cmap='coolwarm',fmt=".2f")
# ----> 3 sns.show()
#
# AttributeError: module 'seaborn' has no attribute 'show'

# %%
diamonds_df_data = diamonds_df
diamonds_df_data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
columns = diamonds_df_data.columns
for column in columns:
  plt.scatter(diamonds_df_data['price'],diamonds_df_data[column])
  plt.xlabel('price')
  plt.ylabel(column)
  plt.show()

# %%
def remove_outliners(df,column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3-Q1
  lv = Q1 - 1.5 * IQR
  uv = Q3 + 1.5 * IQR
  return df[(df[column] >= lv) & (df[column] <= uv)]
for column in columns:
  remove_outliners(diamonds_df_data,column)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  r2_score
X = diamonds_df_data.drop(['price'],axis=1)
y = diamonds_df_data['price']
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)
lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)
y_pred = lin_reg.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8863641648837631

# %%
r2_score(y_train,lin_reg.predict(x_train))
# Out:
# 0.8845117910043304

# %%
pd.to_csv('drive/MyDrive/CL/Day_2')
