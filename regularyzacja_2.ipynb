# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
path_to_file = '/drive/MyDrive/diamonds_preprocessed.csv'

# %%
import pandas as pd
diamonds_df = pd.read_csv(path_to_file)
diamonds_df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53894   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 53895   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 53896   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 53897   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53898   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [53899 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
X = diamonds_df.drop(['price'],axis=1)
y = diamonds_df['price']
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import Lasso,Ridge
lm = Lasso()
rm = Ridge()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import numpy as np

# %%
def print_metrics(y_true,y_pred,alpha):
  r2 = r2_score(y_true,y_pred)
  MAE = mean_absolute_error(y_true,y_pred)
  MSE = mean_squared_error(y_true,y_pred)
  rmse = np.sqrt(MSE)
  print(f"Metrics for alpha={alpha}):")
  print(f"R2: {r2}")
  print(f"MAE: {MAE}")
  print(f"MSE: {MSE}")
  print(f"RMSE: {rmse}")
  print("-" * 30)

# %%
alphas = [0.01,0.1,1,10,100]
for alpha in alphas:
  model_lasso = Lasso()
  model_lasso.fit(x_train,y_train)
  y_pred_train_lasso = model_lasso.predict(x_train)
  y_pred_test_lasso = model_lasso.predict(x_test)

  print_metrics(y_train,y_pred_train_lasso,alpha)
  print_metrics(y_test,y_pred_test_lasso,alpha)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+09, tolerance: 5.960e+07
#   model = cd_fast.enet_coordinate_descent(
# Metrics for alpha=0.01):
# R2: 0.886474562130322
# MAE: 851.4300081194535
# MSE: 1793490.970971871
# RMSE: 1339.2128176551594
# ------------------------------
# Metrics for alpha=0.01):
# R2: 0.8870040713057306
# MAE: 857.274473568025
# MSE: 1822540.4126057425
# RMSE: 1350.0149675487833
# ------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+09, tolerance: 5.960e+07
#   model = cd_fast.enet_coordinate_descent(
# Metrics for alpha=0.1):
# R2: 0.886474562130322
# MAE: 851.4300081194535
# MSE: 1793490.970971871
# RMSE: 1339.2128176551594
# ------------------------------
# Metrics for alpha=0.1):
# R2: 0.8870040713057306
# MAE: 857.274473568025
# MSE: 1822540.4126057425
# RMSE: 1350.0149675487833
# ------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+09, tolerance: 5.960e+07
#   model = cd_fast.enet_coordinate_descent(
# Metrics for alpha=1):
# R2: 0.886474562130322
# MAE: 851.4300081194535
# MSE: 1793490.970971871
# RMSE: 1339.2128176551594
# ------------------------------
# Metrics for alpha=1):
# R2: 0.8870040713057306
# MAE: 857.274473568025
# MSE: 1822540.4126057425
# RMSE: 1350.0149675487833
# ------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+09, tolerance: 5.960e+07
#   model = cd_fast.enet_coordinate_descent(
# Metrics for alpha=10):
# R2: 0.886474562130322
# MAE: 851.4300081194535
# MSE: 1793490.970971871
# RMSE: 1339.2128176551594
# ------------------------------
# Metrics for alpha=10):
# R2: 0.8870040713057306
# MAE: 857.274473568025
# MSE: 1822540.4126057425
# RMSE: 1350.0149675487833
# ------------------------------
# Metrics for alpha=100):
# R2: 0.886474562130322
# MAE: 851.4300081194535
# MSE: 1793490.970971871
# RMSE: 1339.2128176551594
# ------------------------------
# Metrics for alpha=100):
# R2: 0.8870040713057306
# MAE: 857.274473568025
# MSE: 1822540.4126057425
# RMSE: 1350.0149675487833
# ------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+09, tolerance: 5.960e+07
#   model = cd_fast.enet_coordinate_descent(

# %%
alphas = [0.01,0.1,1,10,100]

for alpha in alphas:
  model_lasso = Ridge()
  model_lasso.fit(x_train_scaled,y_train)
  y_pred_train_lasso = model_lasso.predict(x_train_scaled)
  y_pred_test_lasso = model_lasso.predict(x_test_scaled)

  print_metrics(y_train,y_pred_train_lasso,alpha)
  print_metrics(y_test,y_pred_test_lasso,alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-60e1a3f2dea2> in <cell line: 3>()
#       3 for alpha in alphas:
#       4   model_lasso = Ridge()
# ----> 5   model_lasso.fit(x_train_scaled,y_train)
#       6   y_pred_train_lasso = model_lasso.predict(x_train_scaled)
#       7   y_pred_test_lasso = model_lasso.predict(x_test_scaled)
#
# NameError: name 'x_train_scaled' is not defined
