# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/CL/Day 4/imdb_reviews.csv',sep=';')

# %%
df
# Out:
#                                        review,sentiment Unnamed: 1 Unnamed: 2  \
# 0     Titanic is a long but well made tragic adventu...        NaN        NaN
# 1     What can be said of this independent effort be...        NaN        NaN
# 2     And maybe, as Fred Sandford used to say, "one ...        NaN        NaN
# 3     This film isn't a comedy, its an expose. I've ...        NaN        NaN
# 4     Except for the acting of Meryl Streep, which i...        NaN        NaN
# ...                                                 ...        ...        ...
# 9995  Our Family and friends enjoyed this movie very...        NaN        NaN
# 9996  This is a great little film, that's very uniqu...        NaN        NaN
# 9997  The first time I watched this show it was OK. ...        NaN        NaN
# 9998  I liked this movie because it basically did mo...        NaN        NaN
# 9999  The cast of this film contain some of New Zeal...        NaN        NaN
#
#      Unnamed: 3 Unnamed: 4
# ...

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
def process_text(line):
  line = line.lower()
  line = re.sub(r'[^a-z\s]', '', line)
  line = " ".join(word for word in line.split() if word not in stop_words)
  return line


df['review_cleaned'] = df['review,sentiment;;;;'].apply(process_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'review'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#                                    review,sentiment;;;;  \
# 0     Titanic is a long but well made tragic adventu...
# 1     What can be said of this independent effort be...
# 2     And maybe, as Fred Sandford used to say, "one ...
# 3     This film isn't a comedy, its an expose. I've ...
# 4     Except for the acting of Meryl Streep, which i...
# ...                                                 ...
# 9995  Our Family and friends enjoyed this movie very...
# 9996  This is a great little film, that's very uniqu...
# 9997  The first time I watched this show it was OK. ...
# 9998  I liked this movie because it basically did mo...
# 9999  The cast of this film contain some of New Zeal...
#
#                                          review_cleaned
# 0     titanic long well made tragic adventure love s...
# 1     said independent effort beyond fact shot telev...
# 2     maybe fred sandford used say one across lips r...
# 3     film isnt comedy expose ive always hated dog s...
# ...

# %%
df.to_csv('/content/drive/MyDrive/CL/Day 4/imdb_preprocessed.csv')
