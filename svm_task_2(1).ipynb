# %%
from google.colab import drive
drive.mount('drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7b0c2cba9ae5> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     281             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     282         )
# --> 283       raise ValueError('mount failed' + extra_reason)
#     284     elif case == 4:
#     285       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
path_to_file = 'drive/MyDrive/CL/Day_2/penguins_df_normalized.csv'
import pandas as pd
penguins_df = pd.read_csv(path_to_file)

# %%
penguins_df.head(10)
# Out:
#    Unnamed: 0 species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0           0  Adelie              39.1             18.7              181.0
# 1           1  Adelie              39.5             17.4              186.0
# 2           2  Adelie              40.3             18.0              195.0
# 3           4  Adelie              36.7             19.3              193.0
# 4           5  Adelie              39.3             20.6              190.0
# 5           6  Adelie              38.9             17.8              181.0
# 6           7  Adelie              39.2             19.6              195.0
# 7          12  Adelie              41.1             17.6              182.0
# 8          13  Adelie              38.6             21.2              191.0
# 9          14  Adelie              34.6             21.1              198.0
#
#    body_mass_g
# 0       3750.0
# 1       3800.0
# 2       3250.0
# 3       3450.0
# 4       3650.0
# 5       3625.0
# 6       4675.0
# 7       3200.0
# 8       3800.0
# 9       4400.0

# %%
from sklearn.model_selection import train_test_split
X = penguins_df.drop(['species'],axis=1)
y = penguins_df['species']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)
from sklearn.svm import SVC
svc = SVC(kernel='poly',degree=10,shrinking=False,probability=True)

# %%
svc.fit(x_train,y_train)
y_pred = svc.predict(x_test)

# %%
from sklearn.metrics import precision_score

# %%
precision = precision_score(y_pred,y_test,average='macro')
precision
# Out:
# 0.6568627450980392
