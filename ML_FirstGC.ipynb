# %%
from google.colab import drive
drive.mount('/drive') # Mount

dataset_path = '/drive/MyDrive/student_scores.csv'
import pandas as pd
print(pd.__version__)

df = pd.read_csv(dataset_path)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# 2.0.3

# %%
df.MathScore
# Out:
# 0        72
# 1        69
# 2        90
# 3        47
# 4        76
#          ..
# 30636    56
# 30637    74
# 30638    36
# 30639    43
# 30640    52
# Name: MathScore, Length: 30641, dtype: int64

# %%
df['TotalScore'] = df['MathScore'] + df['ReadingScore'] + df['WritingScore']

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# 30639         998    male     group A    some high school  free/reduced
# 30640         999  female     group D  associate's degree      standard
#
#         TestPrep  MathScore  ReadingScore  WritingScore  TotalScore
# ...

# %%
df['TotalScore2'] = df[['MathScore','ReadingScore','WritingScore']].sum(axis=1)

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# 30639         998    male     group A    some high school  free/reduced
# 30640         999  female     group D  associate's degree      standard
#
#         TestPrep  MathScore  ReadingScore  WritingScore  TotalScore  \
# ...

# %%
file = df.to_csv(dataset_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-b80391d2b2cf> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import sklearn # Import library
from sklearn.linear_model import LinearRegression # Import class from specific model

# %%
from sklearn.datasets import load_iris, make_classification, make_regression
# Load built-in dataset
data = load_iris()
# Create synthetic classification dataset
data_cl = make_classification(n_samples=1000, n_features=10, n_informative=7, random_state=42)
# Create synthetic regression dataset
data_re = make_regression(n_samples=5000, n_features=8, n_informative=4, random_state=42)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd;

data_df = pd.DataFrame(data=data.data,columns=data.feature_names)

# %%
X = data_df
x_train,x_test,y_train,y_test = train_test_split(data_df,data.target,test_size=0.3,random_state=123)

# %%
x_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 114                5.8               2.8                5.1               2.4
# 136                6.3               3.4                5.6               2.4
# 53                 5.5               2.3                4.0               1.3
# 19                 5.1               3.8                1.5               0.3
# 38                 4.4               3.0                1.3               0.2
# ..                 ...               ...                ...               ...
# 17                 5.1               3.5                1.4               0.3
# 98                 5.1               2.5                3.0               1.1
# 66                 5.6               3.0                4.5               1.5
# 126                6.2               2.8                4.8               1.8
# 109                7.2               3.6                6.1               2.5
#
# [105 rows x 4 columns]

# %%
import sklearn # Import library
from sklearn.linear_model import LinearRegression # Import class from specific model
from sklearn.datasets import load_iris, make_classification, make_regression
# Load built-in dataset
data = load_iris()

# Create synthetic classification dataset
data = make_classification(n_samples=1000, n_features=10, n_informative=7, random_state=42)

# Create synthetic regression dataset
df = make_regression(n_samples=5000, n_features=8, n_informative=4, random_state=42)

# %%
from sklearn.model_selection import train_test_split
# Split data into train and test set
X = df[0]
y = df[1]

# %%
X = df
y = df["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
