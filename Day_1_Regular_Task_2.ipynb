# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
import pandas as pd

# %%
diamonds_df = pd.read_csv('drive/MyDrive/CL/Day_1/diamonds_preprocessed.csv')
diamonds_df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53894   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 53895   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 53896   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 53897   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53898   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [53899 rows x 10 columns]

# %%
# Podziel zbiór danych na treningowy i testowy.
X = diamonds_df.drop(['price'],axis=1)
y = diamonds_df['price']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
lambda_values = [0,0.001,0.01,0.1,1,10,100,1000]
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np
def print_metrics(y_true,y_pred,name_of_class):
  r2 = r2_score(y_true,y_pred)
  mse = mean_squared_error(y_true,y_pred)
  mae = mean_absolute_error(y_true,y_pred)
  rmse = np.sqrt(mse)
  print(f"{name_of_class} R2: {r2} MSE: {mse} MAE: {mae} RMSE: {rmse}")

# %%
from sklearn.linear_model import Lasso,Ridge
best_res = 0
best_lambda = 0
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
for lambda_value in lambda_values:
  ridge = Ridge(alpha=lambda_value)
  ridge.fit(x_train,y_train)
  y_pred = ridge.predict(x_test)
  print(f"lambda: {lambda_value}")
  print_metrics(y_test,y_pred,"Ridge")

  # MSE Porownujemy
# Out:
# lambda: 0
# Ridge R2: 0.8830302762220537 MSE: 1857963.499514325 MAE: 855.2830260735532 RMSE: 1363.0713479177548
# lambda: 0.001
# Ridge R2: 0.8830302442243986 MSE: 1857964.0077695653 MAE: 855.2834986775475 RMSE: 1363.0715343552463
# lambda: 0.01
# Ridge R2: 0.8830299562723204 MSE: 1857968.581640766 MAE: 855.2877513283183 RMSE: 1363.0732121352712
# lambda: 0.1
# Ridge R2: 0.8830270794134286 MSE: 1858014.2780709323 MAE: 855.3302955250208 RMSE: 1363.0899743123828
# lambda: 1
# Ridge R2: 0.8829985809148 MSE: 1858466.9522205563 MAE: 855.7633211360172 RMSE: 1363.256011254143
# lambda: 10
# Ridge R2: 0.8827319124722001 MSE: 1862702.751167672 MAE: 860.3134581950573 RMSE: 1364.8086866545332
# lambda: 100
# Ridge R2: 0.8786992560037369 MSE: 1926758.0321625092 MAE: 911.4283587403224 RMSE: 1388.0770987818037
# lambda: 1000
# Ridge R2: 0.8454018949025618 MSE: 2455657.9864239697 MAE: 1140.2470331622574 RMSE: 1567.053919437353

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
for lambda_value in lambda_values:
  lasso = Lasso(alpha=lambda_value)
  lasso.fit(x_train,y_train)
  y_pred = lasso.predict(x_test)
  print(f"lambda: {lambda_value}")
  print_metrics(y_test,y_pred,"Ridge")

  # MSE Porownujemy
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1152: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.343e+10, tolerance: 6.000e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# ...
