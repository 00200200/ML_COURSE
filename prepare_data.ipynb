# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
path_to_file = "/drive/MyDrive/heart_data.csv"
import pandas as pd
df = pd.read_csv(path_to_file)

# %%
df
# Out:
#      age     sex     chestpain  restbp   chol  fbs  restecg  minhr  maxhr  \
# 0     63    Male       typical     145  233.0  Yes        2    NaN    150
# 1     67    Male  asymptomatic     160  286.0   No        2    NaN    108
# 2     67    Male  asymptomatic     120  229.0   No        2    NaN    129
# 3     37    Male    nonanginal     130    NaN   No        0    NaN    187
# 4     41  Female    nontypical     130  204.0   No        2    NaN    172
# ..   ...     ...           ...     ...    ...  ...      ...    ...    ...
# 308   57    Male    nonanginal     150  168.0   No        0    NaN    174
# 309   48    Male    nontypical     110  229.0   No        0    NaN    168
# 310   54    Male  asymptomatic     140  239.0   No        0    NaN    160
# 311   48  Female    nonanginal     130  275.0   No        0    NaN    139
# 312   49    Male    nontypical     130  266.0   No        0    NaN    171
#
#     exang  oldpeak  slope   ca        thal  ahd
# ...

# %%
df.tail(15)
# Out:
#      age     sex     chestpain  restbp   chol  fbs  restecg  minhr  maxhr  \
# 298   45    Male       typical     110  264.0   No        0    NaN    132
# 299   68    Male  asymptomatic     144  193.0  Yes        0    NaN    141
# 300   57    Male  asymptomatic     130  131.0   No        0    NaN    115
# 301   57  Female    nontypical     130  236.0   No        2    NaN    174
# 302   38    Male    nonanginal     138  175.0   No        0    NaN    173
# 303   57    Male  asymptomatic     140  192.0   No        0    NaN    148
# 304   56  Female    nontypical     140  294.0   No        2    NaN    153
# 305   56    Male    nonanginal     130  256.0  Yes        2    NaN    142
# 306   44    Male    nontypical     120  263.0   No        0    NaN    173
# 307   52    Male    nonanginal     172  199.0  Yes        0    NaN    162
# 308   57    Male    nonanginal     150  168.0   No        0    NaN    174
# 309   48    Male    nontypical     110  229.0   No        0    NaN    168
# ...

# %%
df.duplicated().sum()
df.drop_duplicates()
# Out:
#      age     sex     chestpain  restbp   chol  fbs  restecg  minhr  maxhr  \
# 0     63    Male       typical     145  233.0  Yes        2    NaN    150
# 1     67    Male  asymptomatic     160  286.0   No        2    NaN    108
# 2     67    Male  asymptomatic     120  229.0   No        2    NaN    129
# 3     37    Male    nonanginal     130    NaN   No        0    NaN    187
# 4     41  Female    nontypical     130  204.0   No        2    NaN    172
# ..   ...     ...           ...     ...    ...  ...      ...    ...    ...
# 298   45    Male       typical     110  264.0   No        0    NaN    132
# 299   68    Male  asymptomatic     144  193.0  Yes        0    NaN    141
# 300   57    Male  asymptomatic     130  131.0   No        0    NaN    115
# 301   57  Female    nontypical     130  236.0   No        2    NaN    174
# 302   38    Male    nonanginal     138  175.0   No        0    NaN    173
#
#     exang  oldpeak  slope   ca        thal  ahd
# ...

# %%
df = df.drop(columns=['minhr'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f2997b93fd7e> in <cell line: 1>()
# ----> 1 df = df.drop(columns=['minhr'])
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
df
# Out:
#      age     sex     chestpain  restbp   chol  fbs  restecg  maxhr exang  \
# 0     63    Male       typical     145  233.0  Yes        2    150    No
# 1     67    Male  asymptomatic     160  286.0   No        2    108   Yes
# 2     67    Male  asymptomatic     120  229.0   No        2    129   Yes
# 3     37    Male    nonanginal     130    NaN   No        0    187    No
# 4     41  Female    nontypical     130  204.0   No        2    172    No
# ..   ...     ...           ...     ...    ...  ...      ...    ...   ...
# 308   57    Male    nonanginal     150  168.0   No        0    174    No
# 309   48    Male    nontypical     110  229.0   No        0    168    No
# 310   54    Male  asymptomatic     140  239.0   No        0    160    No
# 311   48  Female    nonanginal     130  275.0   No        0    139    No
# 312   49    Male    nontypical     130  266.0   No        0    171    No
#
#      oldpeak  slope   ca        thal  ahd
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# chestpain    0
# restbp       0
# chol         2
# fbs          0
# restecg      0
# maxhr        0
# exang        0
# oldpeak      0
# slope        0
# ca           4
# thal         2
# ahd          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        313 non-null    int64
#  1   sex        313 non-null    object
#  2   chestpain  313 non-null    object
#  3   restbp     313 non-null    int64
#  4   chol       311 non-null    float64
#  5   fbs        313 non-null    object
#  6   restecg    313 non-null    int64
#  7   maxhr      313 non-null    int64
#  8   exang      313 non-null    object
#  9   oldpeak    313 non-null    float64
#  10  slope      313 non-null    int64
#  11  ca         309 non-null    float64
#  12  thal       311 non-null    object
#  13  ahd        313 non-null    object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 34.4+ KB

# %%
numeric_columns = df.select_dtypes(include=['float64','int64']).columns
numeric_columns
# Out:
# Index(['age', 'restbp', 'chol', 'restecg', 'maxhr', 'oldpeak', 'slope', 'ca'], dtype='object')

# %%
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        313 non-null    int64
#  1   sex        313 non-null    object
#  2   chestpain  313 non-null    object
#  3   restbp     313 non-null    int64
#  4   chol       313 non-null    float64
#  5   fbs        313 non-null    object
#  6   restecg    313 non-null    int64
#  7   maxhr      313 non-null    int64
#  8   exang      313 non-null    object
#  9   oldpeak    313 non-null    float64
#  10  slope      313 non-null    int64
#  11  ca         313 non-null    float64
#  12  thal       311 non-null    object
#  13  ahd        313 non-null    object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 34.4+ KB

# %%
df.duplicated().sum()
# Out:
# 10

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# chestpain    0
# restbp       0
# chol         0
# fbs          0
# restecg      0
# maxhr        0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         2
# ahd          0
# dtype: int64

# %%
df = df.dropna(axis=0).reset_index()

# %%
df
# Out:
#      index  age     sex     chestpain  restbp   chol  fbs  restecg  maxhr  \
# 0        0   63    Male       typical     145  233.0  Yes        2    150
# 1        1   67    Male  asymptomatic     160  286.0   No        2    108
# 2        2   67    Male  asymptomatic     120  229.0   No        2    129
# 3        3   37    Male    nonanginal     130  240.0   No        0    187
# 4        4   41  Female    nontypical     130  204.0   No        2    172
# ..     ...  ...     ...           ...     ...    ...  ...      ...    ...
# 296    298   45    Male       typical     110  264.0   No        0    132
# 297    299   68    Male  asymptomatic     144  193.0  Yes        0    141
# 298    300   57    Male  asymptomatic     130  131.0   No        0    115
# 299    301   57  Female    nontypical     130  236.0   No        2    174
# 300    302   38    Male    nonanginal     138  175.0   No        0    173
#
#     exang  oldpeak  slope   ca        thal  ahd
# ...

# %%
df.isnull().sum()
# Out:
# index        0
# age          0
# sex          0
# chestpain    0
# restbp       0
# chol         0
# fbs          0
# restecg      0
# maxhr        0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# ahd          0
# dtype: int64

# %%
df.value_counts()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      301 non-null    int64
#  1   age        301 non-null    int64
#  2   sex        301 non-null    object
#  3   chestpain  301 non-null    object
#  4   restbp     301 non-null    int64
#  5   chol       301 non-null    float64
#  6   fbs        301 non-null    object
#  7   restecg    301 non-null    int64
#  8   maxhr      301 non-null    int64
#  9   exang      301 non-null    object
#  10  oldpeak    301 non-null    float64
#  11  slope      301 non-null    int64
#  12  ca         301 non-null    float64
#  13  thal       301 non-null    object
#  14  ahd        301 non-null    object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 35.4+ KB

# %%
category_columns = df.select_dtypes(include=['object'])

# %%
for col in category_columns:
  print(df[col].value_counts())
# Out:
# sex
# Male      205
# Female     96
# Name: count, dtype: int64
# chestpain
# asymptomatic     142
# nonanginal        85
# nontypical        48
# typical           23
# nontypica          1
# asymptomaticc      1
# nontypiccal        1
# Name: count, dtype: int64
# fbs
# No     257
# Yes     44
# Name: count, dtype: int64
# exang
# No     203
# Yes     98
# Name: count, dtype: int64
# thal
# normal         163
# reversable     116
# fixed           17
# REversable       1
# FIXED            1
# Reversabble      1
# Normal           1
# Fixed            1
# Name: count, dtype: int64
# ahd
# No     162
# Yes    138
# no       1
# Name: count, dtype: int64

# %%
df['chestpain'] = df['chestpain'].str.replace('nontypicalll','nontypical')
df['thal'] = df['thal'].str.lower().replace('reversabble','reversable').replace('Reversabble','reversable')
df['ahd'] = df['ahd'].str.replace('no','No')

# %%
for col in category_columns:
  print(df[col].value_counts())
# Out:
# sex
# Male      205
# Female     96
# Name: count, dtype: int64
# chestpain
# asymptomatic    143
# nonanginal       85
# nontypical       50
# typical          23
# Name: count, dtype: int64
# fbs
# No     257
# Yes     44
# Name: count, dtype: int64
# exang
# No     203
# Yes     98
# Name: count, dtype: int64
# thal
# normal        164
# reversable    118
# fixed          19
# Name: count, dtype: int64
# ahd
# No     163
# Yes    138
# Name: count, dtype: int64

# %%
df.to_csv('/drive/MyDrive/first_task.csv',index=False)
