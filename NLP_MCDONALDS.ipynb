# %%
from google.colab import drive
drive.mount('drive')
import pandas as pd
import numpy as np
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/CL/Day 4/mcdonalds_reviews.csv',on_bad_lines='skip',sep=',')

# %%
df
# Out:
#                                              reviewer_id  \
# 0      1,"Why does it look like someone spit on my fo...
# 1      I had a normal transaction,  everyone was chil...
# 2      2,"It'd McDonalds. It is what it is as far as ...
# 3      3,"Made a mobile order got to the speaker and ...
# 4      Line was not moving so I had to leave otherwis...
# ...                                                  ...
# 36991                                              33392
# 36992                                              33393
# 36993                                              33394
# 36994  33395,"It's good, but lately it has become ver...
# 36995                                              33396
#
#                             review   rating;;;;;
# 0                              NaN           NaN
# 1                              NaN           NaN
# 2                              NaN           NaN
# 3                              NaN           NaN
# ...
