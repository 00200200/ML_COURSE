# %%
from google.colab import drive
drive.mount('drive')
import pandas as pd
import numpy as np
sonar_df = pd.read_csv('/content/drive/MyDrive/CL/Day 4/sonar.csv', sep=',' )

sonar_df
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# ...

# %%
# sonar_df.drop(['user_id'],inplace=True,axis=1)
# sonar_df['gender'] = pd.get_dummies(sonar_df['gender'],drop_first=True)

# %%
sonar_df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

X = sonar_df.drop(['R'],axis=1)
from sklearn.preprocessing import LabelEncoder

# Poprawna konwersja etykiet z 'R'/'M' na 0/1
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Sprawdzenie unikalnych wartości w y po konwersji
print(np.unique(y))

scaler = StandardScaler()

scaler.fit_transform(X)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# [0 1]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=5, batch_size=10, verbose=1)
# Out:
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.4930 - loss: 0.6925 - val_accuracy: 0.5862 - val_loss: 0.6725
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7381 - loss: 0.6489 - val_accuracy: 0.6552 - val_loss: 0.6668
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7044 - loss: 0.6412 - val_accuracy: 0.6897 - val_loss: 0.6470
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7118 - loss: 0.6241 - val_accuracy: 0.6552 - val_loss: 0.6340
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7070 - loss: 0.6009 - val_accuracy: 0.6552 - val_loss: 0.6163

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75        36
#            1       0.67      0.59      0.63        27
#
#     accuracy                           0.70        63
#    macro avg       0.69      0.69      0.69        63
# weighted avg       0.70      0.70      0.70        63
