# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
path_to_file = '/drive/MyDrive/kc_house_data_preprocessed.csv'
import pandas as pd
house_df = pd.read_csv(path_to_file)

# %%
from sklearn.model_selection import train_test_split
house_df
# Out:
#        Unnamed: 0     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0               0  221900.0         3       1.00         1180      5650
# 1               1  538000.0         3       2.25         2570      7242
# 2               2  180000.0         2       1.00          770     10000
# 3               3  604000.0         4       3.00         1960      5000
# 4               4  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608       21608  360000.0         3       2.50         1530      1131
# 21609       21609  400000.0         4       2.50         2310      5813
# 21610       21610  402101.0         2       0.75         1020      1350
# 21611       21611  400000.0         3       2.50         1600      2388
# 21612       21612  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
X = house_df.drop(['price'],axis=1)
y = house_df['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import numpy as np

# %%
def print_metrics(y_true,y_pred,alpha):
  r2 = r2_score(y_true,y_pred)
  MAE = mean_absolute_error(y_true,y_pred)
  MSE = mean_squared_error(y_true,y_pred)
  rmse = np.sqrt(MSE)
  print(f"Metrics for alpha={alpha}):")
  print(f"R2: {r2}")
  print(f"MAE: {MAE}")
  print(f"MSE: {MSE}")
  print(f"RMSE: {rmse}")
  print("-" * 30)

from sklearn.linear_model import Lasso,Ridge,LinearRegression

# %%
alphas = [0.01,0.1,1,10,100]

for alpha in alphas:
  model_lasso = Lasso()
  model_lasso.fit(x_train_scaled,y_train)
  y_pred_train_lasso = model_lasso.predict(x_train_scaled)
  y_pred_test_lasso = model_lasso.predict(x_test_scaled)

  print_metrics(y_train,y_pred_train_lasso,alpha)
  print_metrics(y_test,y_pred_test_lasso,alpha)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.988e+13, tolerance: 2.073e+11
#   model = cd_fast.enet_coordinate_descent(
# Metrics for alpha=0.01):
# R2: 0.6970961065111984
# MAE: 127508.90383252832
# MSE: 41494952608.31229
# RMSE: 203703.09916226676
# ------------------------------
# Metrics for alpha=0.01):
# R2: 0.7054600899111805
# MAE: 125346.53532812123
# MSE: 38174698045.3635
# RMSE: 195383.4641042161
# ------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.988e+13, tolerance: 2.073e+11
# ...

# %%
alphas = [0.01,0.1,1,10,100]

for alpha in alphas:
  model_lasso = Ridge()
  model_lasso.fit(x_train_scaled,y_train)
  y_pred_train_lasso = model_lasso.predict(x_train_scaled)
  y_pred_test_lasso = model_lasso.predict(x_test_scaled)

  print_metrics(y_train,y_pred_train_lasso,alpha)
  print_metrics(y_test,y_pred_test_lasso,alpha)
# Out:
# Metrics for alpha=0.01):
# R2: 0.697096104712694
# MAE: 127506.24486620245
# MSE: 41494952854.69028
# RMSE: 203703.09976701453
# ------------------------------
# Metrics for alpha=0.01):
# R2: 0.7054617002006245
# MAE: 125344.0590017378
# MSE: 38174489339.13664
# RMSE: 195382.930009601
# ------------------------------
# Metrics for alpha=0.1):
# R2: 0.697096104712694
# MAE: 127506.24486620245
# MSE: 41494952854.69028
# RMSE: 203703.09976701453
# ------------------------------
# Metrics for alpha=0.1):
# R2: 0.7054617002006245
# MAE: 125344.0590017378
# MSE: 38174489339.13664
# RMSE: 195382.930009601
# ------------------------------
# Metrics for alpha=1):
# R2: 0.697096104712694
# MAE: 127506.24486620245
# MSE: 41494952854.69028
# RMSE: 203703.09976701453
# ------------------------------
# Metrics for alpha=1):
# R2: 0.7054617002006245
# MAE: 125344.0590017378
# MSE: 38174489339.13664
# RMSE: 195382.930009601
# ------------------------------
# Metrics for alpha=10):
# ...
