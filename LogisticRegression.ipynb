# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
path_to_file = '/drive/MyDrive/CL/Day_2/lumbar_df_normalized.csv'

# %%
import pandas as pd
lumbar_df = pd.read_csv(path_to_file)
lumbar_df
# Out:
#      pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# 0            0.477474             0.170850               0.300063
# 1            0.306835             0.079040               0.196523
# 2            0.473200             0.152745               0.344369
# 3            0.491613             0.174895               0.314357
# 4            0.384294             0.074613               0.218901
# ..                ...                  ...                    ...
# 305          0.349707             0.099405               0.262808
# 306          0.397893             0.152863               0.215561
# 307          0.398932             0.147343               0.299753
# 308          0.326225             0.062668               0.299770
# 309          0.247451             0.037101               0.267921
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis  class
# 0        0.306625       0.747508                 -0.001927      1
# 1        0.227795       0.898781                  0.035857      1
# 2        0.320454       0.728616                 -0.024270      1
# 3        0.316718       0.722684                  0.079538      1
# 4        0.309680       0.836173                  0.061212      1
# ..            ...            ...                       ...    ...
# 305      0.250302       0.857405                 -0.030992      0
# 306      0.245030       0.843681                 -0.003106      0
# 307      0.251588       0.815896                 -0.017580      0
# 308      0.263556       0.854590                  0.001548      0
# 309      0.210350       0.906290                 -0.001457      0
#
# [310 rows x 7 columns]

# %%
lumbar_df.value_counts()
# Out:
# pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  sacral_slope  pelvic_radius  degree_spondylolisthesis  class
# 0.200486          0.082497             0.107343               0.117989      0.959983       -0.077388                 1        1
# 0.418878          0.106523             0.333350               0.312355      0.753685        0.190958                 1        1
# 0.424336          0.133333             0.202431               0.291002      0.822440        0.009680                 0        1
# 0.424267          0.075669             0.469970               0.348599      0.659457        0.192342                 1        1
# 0.423115          0.128362             0.320660               0.294754      0.709807        0.333119                 1        1
#                                                                                                                              ..
# 0.349707          0.099405             0.262808               0.250302      0.857405       -0.030992                 0        1
# 0.349326          0.091640             0.237271               0.257686      0.859045        0.094422                 0        1
# 0.348666          0.120106             0.269175               0.228560      0.859756       -0.011487                 0        1
# 0.347530          0.062821             0.217288               0.284709      0.864158        0.015306                 1        1
# 0.619077          0.201475             0.266394               0.417602      0.424568        0.387989                 1        1
# Name: count, Length: 310, dtype: int64

# %%
X = lumbar_df.drop('class',axis=1)
y = lumbar_df['class']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state =42)

# %%
from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression(C=1.1)
lreg.fit(x_train,y_train)
y_pred = lreg.predict(x_test)

# %%
from sklearn.metrics import precision_score

precission = precision_score(y_test,y_pred)

# %%
print(precission)
# Out:
# 0.8
